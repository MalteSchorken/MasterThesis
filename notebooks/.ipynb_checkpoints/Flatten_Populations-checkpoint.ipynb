# %%
# %cd ..
# Out:
# C:\Users\malte\EvoMUSART23-repro-code

# %%
import os
import pickle
from evoaudio.population import Population

# Base directory where population logs are stored
data_base_dir = os.path.join("experiments", "ground_truth_scan")

# Features and distances (adjust if needed)
audio_features = [
    "cqt", "hybrid_cqt", "iirt", "melspectrogram", "mfcc",
    "pseudo_cqt", "spectral", "stft", "tonnetz", "vqt"
]
distance_measures = [
    "itakura_saito", "beta_divergence", "cosh", "kl_divergence",
    "js_divergence", "manhattan", "euclidean", "chebyshev",
    "wasserstein", "cosine"
]

for feature in audio_features:
    for dist in distance_measures:
        pop_file = os.path.join(
            data_base_dir,
            feature,
            f"{feature}_{dist}_populations.pkl"
        )

        if not os.path.exists(pop_file):
            print(f"Warning: {pop_file} not found")
            continue

        with open(pop_file, "rb") as f:
            result_logs = pickle.load(f)  # [(idx, Population), ...]

        # Flatten all populations in memory
        for i, (idx, pop) in enumerate(result_logs):
            pop._flatten()  # flatten in place
            result_logs[i] = (idx, pop)  # ensure tuple stays updated

        # Overwrite the original file
        with open(pop_file, "wb") as f:
            pickle.dump(result_logs, f)

        print(f"Flattened populations in {pop_file}")
# Out:
# Flattened populations in experiments\ground_truth_scan\cqt\cqt_itakura_saito_populations.pkl
# Flattened populations in experiments\ground_truth_scan\cqt\cqt_beta_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\cqt\cqt_cosh_populations.pkl
# Flattened populations in experiments\ground_truth_scan\cqt\cqt_kl_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\cqt\cqt_js_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\cqt\cqt_manhattan_populations.pkl
# Flattened populations in experiments\ground_truth_scan\cqt\cqt_euclidean_populations.pkl
# Flattened populations in experiments\ground_truth_scan\cqt\cqt_chebyshev_populations.pkl
# Flattened populations in experiments\ground_truth_scan\cqt\cqt_wasserstein_populations.pkl
# Flattened populations in experiments\ground_truth_scan\cqt\cqt_cosine_populations.pkl
# Flattened populations in experiments\ground_truth_scan\hybrid_cqt\hybrid_cqt_itakura_saito_populations.pkl
# Flattened populations in experiments\ground_truth_scan\hybrid_cqt\hybrid_cqt_beta_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\hybrid_cqt\hybrid_cqt_cosh_populations.pkl
# Flattened populations in experiments\ground_truth_scan\hybrid_cqt\hybrid_cqt_kl_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\hybrid_cqt\hybrid_cqt_js_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\hybrid_cqt\hybrid_cqt_manhattan_populations.pkl
# Flattened populations in experiments\ground_truth_scan\hybrid_cqt\hybrid_cqt_euclidean_populations.pkl
# Flattened populations in experiments\ground_truth_scan\hybrid_cqt\hybrid_cqt_chebyshev_populations.pkl
# Flattened populations in experiments\ground_truth_scan\hybrid_cqt\hybrid_cqt_wasserstein_populations.pkl
# Flattened populations in experiments\ground_truth_scan\hybrid_cqt\hybrid_cqt_cosine_populations.pkl
# Flattened populations in experiments\ground_truth_scan\iirt\iirt_itakura_saito_populations.pkl
# Flattened populations in experiments\ground_truth_scan\iirt\iirt_beta_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\iirt\iirt_cosh_populations.pkl
# Flattened populations in experiments\ground_truth_scan\iirt\iirt_kl_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\iirt\iirt_js_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\iirt\iirt_manhattan_populations.pkl
# Flattened populations in experiments\ground_truth_scan\iirt\iirt_euclidean_populations.pkl
# Flattened populations in experiments\ground_truth_scan\iirt\iirt_chebyshev_populations.pkl
# Flattened populations in experiments\ground_truth_scan\iirt\iirt_wasserstein_populations.pkl
# Flattened populations in experiments\ground_truth_scan\iirt\iirt_cosine_populations.pkl
# Flattened populations in experiments\ground_truth_scan\melspectrogram\melspectrogram_itakura_saito_populations.pkl
# Flattened populations in experiments\ground_truth_scan\melspectrogram\melspectrogram_beta_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\melspectrogram\melspectrogram_cosh_populations.pkl
# Flattened populations in experiments\ground_truth_scan\melspectrogram\melspectrogram_kl_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\melspectrogram\melspectrogram_js_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\melspectrogram\melspectrogram_manhattan_populations.pkl
# Flattened populations in experiments\ground_truth_scan\melspectrogram\melspectrogram_euclidean_populations.pkl
# Flattened populations in experiments\ground_truth_scan\melspectrogram\melspectrogram_chebyshev_populations.pkl
# Flattened populations in experiments\ground_truth_scan\melspectrogram\melspectrogram_wasserstein_populations.pkl
# Flattened populations in experiments\ground_truth_scan\melspectrogram\melspectrogram_cosine_populations.pkl
# Flattened populations in experiments\ground_truth_scan\mfcc\mfcc_itakura_saito_populations.pkl
# Flattened populations in experiments\ground_truth_scan\mfcc\mfcc_beta_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\mfcc\mfcc_cosh_populations.pkl
# Flattened populations in experiments\ground_truth_scan\mfcc\mfcc_kl_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\mfcc\mfcc_js_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\mfcc\mfcc_manhattan_populations.pkl
# Flattened populations in experiments\ground_truth_scan\mfcc\mfcc_euclidean_populations.pkl
# Flattened populations in experiments\ground_truth_scan\mfcc\mfcc_chebyshev_populations.pkl
# Flattened populations in experiments\ground_truth_scan\mfcc\mfcc_wasserstein_populations.pkl
# Flattened populations in experiments\ground_truth_scan\mfcc\mfcc_cosine_populations.pkl
# Flattened populations in experiments\ground_truth_scan\pseudo_cqt\pseudo_cqt_itakura_saito_populations.pkl
# Flattened populations in experiments\ground_truth_scan\pseudo_cqt\pseudo_cqt_beta_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\pseudo_cqt\pseudo_cqt_cosh_populations.pkl
# Flattened populations in experiments\ground_truth_scan\pseudo_cqt\pseudo_cqt_kl_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\pseudo_cqt\pseudo_cqt_js_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\pseudo_cqt\pseudo_cqt_manhattan_populations.pkl
# Flattened populations in experiments\ground_truth_scan\pseudo_cqt\pseudo_cqt_euclidean_populations.pkl
# Flattened populations in experiments\ground_truth_scan\pseudo_cqt\pseudo_cqt_chebyshev_populations.pkl
# Flattened populations in experiments\ground_truth_scan\pseudo_cqt\pseudo_cqt_wasserstein_populations.pkl
# Flattened populations in experiments\ground_truth_scan\pseudo_cqt\pseudo_cqt_cosine_populations.pkl
# Flattened populations in experiments\ground_truth_scan\spectral\spectral_itakura_saito_populations.pkl
# Flattened populations in experiments\ground_truth_scan\spectral\spectral_beta_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\spectral\spectral_cosh_populations.pkl
# Flattened populations in experiments\ground_truth_scan\spectral\spectral_kl_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\spectral\spectral_js_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\spectral\spectral_manhattan_populations.pkl
# Flattened populations in experiments\ground_truth_scan\spectral\spectral_euclidean_populations.pkl
# Flattened populations in experiments\ground_truth_scan\spectral\spectral_chebyshev_populations.pkl
# Flattened populations in experiments\ground_truth_scan\spectral\spectral_wasserstein_populations.pkl
# Flattened populations in experiments\ground_truth_scan\spectral\spectral_cosine_populations.pkl
# Flattened populations in experiments\ground_truth_scan\stft\stft_itakura_saito_populations.pkl
# Flattened populations in experiments\ground_truth_scan\stft\stft_beta_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\stft\stft_cosh_populations.pkl
# Flattened populations in experiments\ground_truth_scan\stft\stft_kl_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\stft\stft_js_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\stft\stft_manhattan_populations.pkl
# Flattened populations in experiments\ground_truth_scan\stft\stft_euclidean_populations.pkl
# Flattened populations in experiments\ground_truth_scan\stft\stft_chebyshev_populations.pkl
# Flattened populations in experiments\ground_truth_scan\stft\stft_wasserstein_populations.pkl
# Flattened populations in experiments\ground_truth_scan\stft\stft_cosine_populations.pkl
# Flattened populations in experiments\ground_truth_scan\tonnetz\tonnetz_itakura_saito_populations.pkl
# Flattened populations in experiments\ground_truth_scan\tonnetz\tonnetz_beta_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\tonnetz\tonnetz_cosh_populations.pkl
# Flattened populations in experiments\ground_truth_scan\tonnetz\tonnetz_kl_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\tonnetz\tonnetz_js_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\tonnetz\tonnetz_manhattan_populations.pkl
# Flattened populations in experiments\ground_truth_scan\tonnetz\tonnetz_euclidean_populations.pkl
# Flattened populations in experiments\ground_truth_scan\tonnetz\tonnetz_chebyshev_populations.pkl
# Flattened populations in experiments\ground_truth_scan\tonnetz\tonnetz_wasserstein_populations.pkl
# Flattened populations in experiments\ground_truth_scan\tonnetz\tonnetz_cosine_populations.pkl
# Flattened populations in experiments\ground_truth_scan\vqt\vqt_itakura_saito_populations.pkl
# Flattened populations in experiments\ground_truth_scan\vqt\vqt_beta_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\vqt\vqt_cosh_populations.pkl
# Flattened populations in experiments\ground_truth_scan\vqt\vqt_kl_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\vqt\vqt_js_divergence_populations.pkl
# Flattened populations in experiments\ground_truth_scan\vqt\vqt_manhattan_populations.pkl
# Flattened populations in experiments\ground_truth_scan\vqt\vqt_euclidean_populations.pkl
# Flattened populations in experiments\ground_truth_scan\vqt\vqt_chebyshev_populations.pkl
# Flattened populations in experiments\ground_truth_scan\vqt\vqt_wasserstein_populations.pkl
# Flattened populations in experiments\ground_truth_scan\vqt\vqt_cosine_populations.pkl

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Nov 28 16:45:52 2025

@author: malte
"""

import pickle
import os

from evoaudio.base_algorithms import approximate_piece
from evoaudio.sample_library import SampleLibrary
from evoaudio.mutations import Mutator
from evoaudio.individual import BaseIndividual

# Experiment parameters
RESULTS_PATH = "./experiments/moea_results_singleprocess.pkl"

N_RUNS = 100
MAX_STEPS = 5000
POPSIZE = 10
N_OFFSPRING = 1
ALPHA = 5
BETA = 10
L_BOUND = 1
U_BOUND = 10
ZETA = 0.9954


def run_experiment(target_individuals, sample_lib):
    """
    Run the approximation for a list of target individuals.
    Stores only final Population objects.
    """
    results = []

    for true_id, true_ind in target_individuals:
        print(f"Run {true_id + 1}/{len(target_individuals)}: {true_ind}")

        mutator = Mutator(sample_library=sample_lib, alpha=ALPHA, beta=BETA, l_bound=L_BOUND, u_bound=U_BOUND)

        final_population = approximate_piece(
            target_y=true_ind.to_mixdown(),
            max_steps=MAX_STEPS,
            sample_lib=sample_lib,
            popsize=POPSIZE,
            n_offspring=N_OFFSPRING,
            onset_frac=1,
            zeta=ZETA,
            early_stopping_fitness=None,
            mutator=mutator,
            onsets=[0],
            verbose=True,
            parent_selection="random",
            survivor_selection="worst",
            objectives=[("stft", "cosh")]
        )

        results.append((true_id, final_population))
        print(f"Finished Run {true_id + 1}/{len(target_individuals)}\n{'-' * 40}")

    return results


if __name__ == "__main__":
    # Load target individuals
    file_path = os.path.join("experiments", "ground_truth_scan", "ground_truth_drums_dataset.pkl")
    with open(file_path, "rb") as f:
        restored_individuals = pickle.load(f)

    restored_with_ids = [(idx, ind) for idx, ind in enumerate(restored_individuals)]

    # Initialize sample library
    sample_lib = SampleLibrary()

    # Run the experiment
    result_logs = run_experiment(restored_with_ids, sample_lib)

    # Save final populations
    os.makedirs(os.path.dirname(RESULTS_PATH), exist_ok=True)
    with open(RESULTS_PATH, "wb") as f:
        pickle.dump(result_logs, f)

    print(f"Experiment finished. Final populations saved to {RESULTS_PATH}")
# Out:
# Loading samples:   0%|          | 0/6826 [00:00<?, ?it/s]
# Run 1/100: Fitness: inf | (Drums, AR80s_BlackKit, Snare_WiresOff), (Drums, AR50s_SpringKit, Snare_RimOnly)
# Initializing Population: 100%|███████████████████████████████████████████████████████| 10/10 [00:00<00:00, 1665.27it/s]
# Calculating initial fitness: 100%|████████████████████████████████████████████████████| 10/10 [00:00<00:00, 156.10it/s]
#   0%| | 0/5000 [00:00<?, ?it/s, Best individual: Fitness: [1.79603516] | (Drums, ARVintage_IvoryKit, Snare_WiresOff), (
# Memory usage: 3625.84 MB
# Memory usage: 3626.00 MB
# Memory usage: 3626.01 MB
# Memory usage: 3626.01 MB
# Memory usage: 3626.01 MB
# Memory usage: 3626.01 MB
# Memory usage: 3626.01 MB
# Memory usage: 3626.01 MB
# Memory usage: 3626.01 MB
#   0%| | 10/5000 [00:00<00:52, 94.24it/s, Best individual: Fitness: [0.98485149] | (Panflute, panflute, f2), (Drums, AR7
# Memory usage: 3626.86 MB
# Memory usage: 3626.86 MB
# Memory usage: 3626.86 MB
# Memory usage: 3626.95 MB
# Memory usage: 3626.95 MB
# Memory usage: 3626.95 MB
# Memory usage: 3626.96 MB
# Memory usage: 3626.96 MB
#   0%| | 20/5000 [00:00<00:54, 91.74it/s, Best individual: Fitness: [0.98485149] | (Panflute, panflute, f2), (Drums, AR7
# Memory usage: 3626.96 MB
# Memory usage: 3626.96 MB
# Memory usage: 3626.97 MB
# Memory usage: 3626.97 MB
# Memory usage: 3626.97 MB
# Memory usage: 3626.97 MB
# Memory usage: 3626.97 MB
# Memory usage: 3626.97 MB
# Memory usage: 3626.97 MB
#   1%| | 30/5000 [00:00<00:53, 93.08it/s, Best individual: Fitness: [0.98485149] | (Panflute, panflute, f2), (Drums, AR7
# Memory usage: 3626.97 MB
# Memory usage: 3626.97 MB
# Memory usage: 3627.36 MB
# Memory usage: 3627.36 MB
# Memory usage: 3627.36 MB
# Memory usage: 3627.36 MB
# Memory usage: 3627.36 MB
# Memory usage: 3627.36 MB
# Memory usage: 3627.36 MB
#   1%| | 40/5000 [00:00<00:52, 93.87it/s, Best individual: Fitness: [0.98485149] | (Panflute, panflute, f2), (Drums, AR7
# Memory usage: 3627.36 MB
# Memory usage: 3627.36 MB
# Memory usage: 3627.36 MB
# Memory usage: 3627.36 MB
# Memory usage: 3627.36 MB
# Memory usage: 3627.36 MB
# Memory usage: 3627.36 MB
# Memory usage: 3627.36 MB
# Memory usage: 3627.36 MB
#   1%| | 51/5000 [00:00<00:50, 97.56it/s, Best individual: Fitness: [0.98485149] | (Panflute, panflute, f2), (Drums, AR7
# Memory usage: 3627.44 MB
# Memory usage: 3627.44 MB
# Memory usage: 3627.44 MB
# Memory usage: 3627.50 MB
# Memory usage: 3627.50 MB
# Memory usage: 3627.50 MB
# Memory usage: 3627.50 MB
# Memory usage: 3627.52 MB
# Memory usage: 3627.52 MB
#   1%| | 61/5000 [00:00<00:51, 95.06it/s, Best individual: Fitness: [0.98485149] | (Panflute, panflute, f2), (Drums, AR7
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
#   1%| | 61/5000 [00:00<00:51, 95.06it/s, Best individual: Fitness: [0.98485149] | (Panflute, panflute, f2), (Drums, AR7
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
#   1%| | 71/5000 [00:00<00:52, 94.23it/s, Best individual: Fitness: [0.90411639] | (ElectricBass, Scarbee_Rickenbacker_B
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
#   2%| | 81/5000 [00:00<00:51, 95.23it/s, Best individual: Fitness: [0.90411639] | (ElectricBass, Scarbee_Rickenbacker_B
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
#   2%| | 91/5000 [00:01<00:51, 94.80it/s, Best individual: Fitness: [0.86674471] | (AcousticGuitar, tr111AGRPM, f2), (Dr
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
#   2%| | 101/5000 [00:01<00:52, 93.16it/s, Best individual: Fitness: [0.86674471] | (AcousticGuitar, tr111AGRPM, f2), (D
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
#   2%| | 111/5000 [00:01<00:52, 93.92it/s, Best individual: Fitness: [0.86674471] | (AcousticGuitar, tr111AGRPM, f2), (D
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
#   2%| | 121/5000 [00:01<00:53, 91.27it/s, Best individual: Fitness: [0.86674471] | (AcousticGuitar, tr111AGRPM, f2), (D
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.39 MB
# Memory usage: 3628.41 MB
# Memory usage: 3628.41 MB
# Memory usage: 3628.99 MB
#   2%| | 121/5000 [00:01<00:53, 91.27it/s, Best individual: Fitness: [0.69333675] | (AcousticGuitar, tr111AGRPM, gis3),
# Memory usage: 3628.99 MB
# Memory usage: 3629.00 MB
# Memory usage: 3629.00 MB
# Memory usage: 3629.00 MB
# Memory usage: 3629.00 MB
# Memory usage: 3629.00 MB
# Memory usage: 3629.00 MB
# Memory usage: 3629.09 MB
# Memory usage: 3629.09 MB
#   3%| | 131/5000 [00:01<00:54, 89.16it/s, Best individual: Fitness: [0.69333675] | (AcousticGuitar, tr111AGRPM, gis3),
# Memory usage: 3629.20 MB
# Memory usage: 3629.20 MB
# Memory usage: 3629.20 MB
# Memory usage: 3629.20 MB
# Memory usage: 3629.20 MB
# Memory usage: 3629.20 MB
# Memory usage: 3629.20 MB
#   3%| | 140/5000 [00:01<00:54, 88.51it/s, Best individual: Fitness: [0.69333675] | (AcousticGuitar, tr111AGRPM, gis3),
# Memory usage: 3629.20 MB
# Memory usage: 3629.20 MB
# Memory usage: 3629.20 MB
# Memory usage: 3629.20 MB
# Memory usage: 3629.20 MB
# Memory usage: 3629.20 MB
# Memory usage: 3629.20 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
#   3%| | 150/5000 [00:01<00:53, 90.33it/s, Best individual: Fitness: [0.69333675] | (AcousticGuitar, tr111AGRPM, gis3),
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
#   3%| | 161/5000 [00:01<00:51, 93.12it/s, Best individual: Fitness: [0.69333675] | (AcousticGuitar, tr111AGRPM, gis3),
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
#   3%| | 171/5000 [00:01<00:50, 94.86it/s, Best individual: Fitness: [0.69333675] | (AcousticGuitar, tr111AGRPM, gis3),
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
# Memory usage: 3629.21 MB
